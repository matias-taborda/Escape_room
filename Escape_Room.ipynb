# %%
print("🗝️ ESCAPE ROOM")
print("Estás atrapado en una habitación.\n")

# Estado del juego
tiene_llave = False
puerta_abierta = False

while True:
    print("¿Qué querés hacer?")
    print("- mirar")
    print("- revisar cajón")
    print("- abrir puerta")
    print("- salir")

    accion = input("> ").lower()

    if accion == "mirar":
        print("Ves una habitación pequeña, una puerta cerrada y un cajón.\n")

    elif accion == "revisar cajón":
        if not tiene_llave:
            print("Encontraste una llave 🔑\n")
            tiene_llave = True
        else:
            print("El cajón está vacío.\n")

    elif accion == "abrir puerta":
        if tiene_llave:
            print("Usás la llave y abrís la puerta 🚪")
            print("🎉 ¡Escapaste! ¡Ganaste!")
            break
        else:
            print("La puerta está cerrada con llave.\n")

    elif accion == "salir":
        print("Te rendiste 😢")
        break

    else:
        print("❌ Acción no válida\n")
# Out:
# 🗝️ ESCAPE ROOM
# Estás atrapado en una habitación.
#
# ¿Qué querés hacer?
# - mirar
# - revisar cajón
# - abrir puerta
# - salir
# >  mirar
# Ves una habitación pequeña, una puerta cerrada y un cajón.
#
# ¿Qué querés hacer?
# - mirar
# - revisar cajón
# - abrir puerta
# - salir
# >  revisar cajon
# ❌ Acción no válida
#
# ¿Qué querés hacer?
# - mirar
# - revisar cajón
# - abrir puerta
# - salir
# >  revisar cajón
# Encontraste una llave 🔑
#
# ¿Qué querés hacer?
# - mirar
# - revisar cajón
# - abrir puerta
# - salir
# >  abrir puerta
# Usás la llave y abrís la puerta 🚪
# 🎉 ¡Escapaste! ¡Ganaste!
